# %%
#Import required libraries and dependencies

from pathlib import Path
import pandas as pd
# %matplotlib inline
import numpy as np

# %%
# Read in Bitcoin csv as a Pandas Dataframe
btc_df = pd.read_csv(
    Path("Resources/BTC-USD.csv"),
    index_col="Date",
    parse_dates=True,
    infer_datetime_format=True
)
# Call the new Dataframe to insure the data was read in properly       
btc_df
# Out:
#                     Open          High           Low         Close  \
# Date
# 2021-05-27  39316.890625  40379.617188  37247.902344  38436.968750
# 2021-05-28  38507.082031  38856.968750  34779.039063  35697.605469
# 2021-05-29  35684.156250  37234.500000  33693.929688  34616.066406
# 2021-05-30  34607.406250  36400.667969  33520.738281  35678.128906
# 2021-05-31  35658.593750  37468.250000  34241.945313  37332.855469
# ...                  ...           ...           ...           ...
# 2022-05-23  30309.396484  30590.585938  28975.560547  29098.910156
# 2022-05-24  29101.125000  29774.355469  28786.589844  29655.585938
# 2022-05-25  29653.134766  30157.785156  29384.949219  29562.361328
# 2022-05-26  29564.777344  29834.160156  28261.906250  29267.224609
# 2022-05-27  29282.712891  29342.943359  28880.873047  28961.142578
#
#                Adj Close       Volume
# Date
# 2021-05-27  38436.968750  43210968721
# 2021-05-28  35697.605469  55200191952
# ...

# %%
# Read in Ethereum CSV as a Pandas Dataframe
eth_df = pd.read_csv(
    Path("Resources/ETH-USD.csv"),
    index_col="Date",
    parse_dates=True,
    infer_datetime_format=True
)
# Call the new Dataframe to insure the data was read in properly
eth_df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2021-05-27  2888.752441  2888.752441  2642.607910  2736.488525  2736.488525
# 2021-05-28  2742.468994  2761.363281  2336.361328  2419.906250  2419.906250
# 2021-05-29  2414.067139  2566.938477  2208.490967  2279.514160  2279.514160
# 2021-05-30  2278.288818  2472.187744  2188.834473  2390.305420  2390.305420
# 2021-05-31  2387.198486  2715.854980  2279.505127  2714.945313  2714.945313
# ...                 ...          ...          ...          ...          ...
# 2022-05-23  2042.344727  2080.333496  1964.386597  1972.181885  1972.181885
# 2022-05-24  1972.390869  1991.535522  1920.688110  1978.982788  1978.982788
# 2022-05-25  1978.677002  2014.369507  1943.938599  1944.827881  1944.827881
# 2022-05-26  1945.033325  1962.171143  1759.199585  1803.913330  1803.913330
# 2022-05-27  1803.849976  1805.196411  1741.441162  1752.477295  1752.477295
#
#                  Volume
# Date
# ...

# %%
# Read in the S&P 500 csv as a Pandas Dataframe
sp_500_df= pd.read_csv(
    Path("Resources/SP_500_Historical_Data_1 (1).csv"),
    index_col="Date",
    parse_dates=True,
    infer_datetime_format=True
)
# Call the new Dataframe to insure the data was loaded in properly
sp_500_df
# Out:
#                Price      Open      High       Low Vol. Change %
# Date
# 2022-05-13  4,024.70  3,975.30  4,039.40  3,963.20    -    2.41%
# 2022-05-12  3,930.08  3,903.95  3,964.80  3,858.87    -   -0.13%
# 2022-05-11  3,935.18  3,990.08  4,049.09  3,928.82    -   -1.65%
# 2022-05-10  4,001.05  4,035.18  4,068.82  3,958.17    -    0.25%
# 2022-05-09  3,991.24  4,081.27  4,081.27  3,975.48    -   -3.20%
# ...              ...       ...       ...       ...  ...      ...
# 2015-01-08  2,062.14  2,030.61  2,064.08  2,030.61    -    1.79%
# 2015-01-07  2,025.90  2,005.55  2,029.61  2,005.55    -    1.16%
# 2015-01-06  2,002.61  2,022.15  2,030.25  1,992.44    -   -0.89%
# 2015-01-05  2,020.58  2,054.44  2,054.44  2,017.34    -   -1.83%
# 2015-01-02  2,058.20  2,058.90  2,072.36  2,046.04    -   -0.03%
#
# [1855 rows x 6 columns]

# %%
# We dropped the 'Change %' in hopes to convert the data to 'float'
sp_500_df= sp_500_df.drop('Change %', axis=1)

sp_500_df
# Out:
#                Price      Open      High       Low Vol.
# Date
# 2022-05-13  4,024.70  3,975.30  4,039.40  3,963.20    -
# 2022-05-12  3,930.08  3,903.95  3,964.80  3,858.87    -
# 2022-05-11  3,935.18  3,990.08  4,049.09  3,928.82    -
# 2022-05-10  4,001.05  4,035.18  4,068.82  3,958.17    -
# 2022-05-09  3,991.24  4,081.27  4,081.27  3,975.48    -
# ...              ...       ...       ...       ...  ...
# 2015-01-08  2,062.14  2,030.61  2,064.08  2,030.61    -
# 2015-01-07  2,025.90  2,005.55  2,029.61  2,005.55    -
# 2015-01-06  2,002.61  2,022.15  2,030.25  1,992.44    -
# 2015-01-05  2,020.58  2,054.44  2,054.44  2,017.34    -
# 2015-01-02  2,058.20  2,058.90  2,072.36  2,046.04    -
#
# [1855 rows x 5 columns]

# %%
# We dropped the "Vol." column in hopes it would let us convert the rest of the data to 'float'
sp_500_df=sp_500_df.drop('Vol.', axis=1)

sp_500_df
# Out:
#                Price      Open      High       Low
# Date
# 2022-05-13  4,024.70  3,975.30  4,039.40  3,963.20
# 2022-05-12  3,930.08  3,903.95  3,964.80  3,858.87
# 2022-05-11  3,935.18  3,990.08  4,049.09  3,928.82
# 2022-05-10  4,001.05  4,035.18  4,068.82  3,958.17
# 2022-05-09  3,991.24  4,081.27  4,081.27  3,975.48
# ...              ...       ...       ...       ...
# 2015-01-08  2,062.14  2,030.61  2,064.08  2,030.61
# 2015-01-07  2,025.90  2,005.55  2,029.61  2,005.55
# 2015-01-06  2,002.61  2,022.15  2,030.25  1,992.44
# 2015-01-05  2,020.58  2,054.44  2,054.44  2,017.34
# 2015-01-02  2,058.20  2,058.90  2,072.36  2,046.04
#
# [1855 rows x 4 columns]

# %%
# Used the 'dtypes' function to see the data types within the S&P dataframe
sp_500_df.dtypes
# Out:
# Price    object
# Open     object
# High     object
# Low      object
# dtype: object

# %%
# Use 'replace' function to drop all , from the S&P dataframe
sp_500_df = sp_500_df.replace(",","", regex=True)

sp_500_df
# Out:
#               Price     Open     High      Low
# Date
# 2022-05-13  4024.70  3975.30  4039.40  3963.20
# 2022-05-12  3930.08  3903.95  3964.80  3858.87
# 2022-05-11  3935.18  3990.08  4049.09  3928.82
# 2022-05-10  4001.05  4035.18  4068.82  3958.17
# 2022-05-09  3991.24  4081.27  4081.27  3975.48
# ...             ...      ...      ...      ...
# 2015-01-08  2062.14  2030.61  2064.08  2030.61
# 2015-01-07  2025.90  2005.55  2029.61  2005.55
# 2015-01-06  2002.61  2022.15  2030.25  1992.44
# 2015-01-05  2020.58  2054.44  2054.44  2017.34
# 2015-01-02  2058.20  2058.90  2072.36  2046.04
#
# [1855 rows x 4 columns]

# %%
#Use 'astype' to convert Objects in S&P dataframe to Float
sp_500_df = sp_500_df.astype('float')

sp_500_df.dtypes
# Out:
# Price    float64
# Open     float64
# High     float64
# Low      float64
# dtype: object

# %%
sp_500_df
# Out:
#               Price     Open     High      Low
# Date
# 2022-05-13  4024.70  3975.30  4039.40  3963.20
# 2022-05-12  3930.08  3903.95  3964.80  3858.87
# 2022-05-11  3935.18  3990.08  4049.09  3928.82
# 2022-05-10  4001.05  4035.18  4068.82  3958.17
# 2022-05-09  3991.24  4081.27  4081.27  3975.48
# ...             ...      ...      ...      ...
# 2015-01-08  2062.14  2030.61  2064.08  2030.61
# 2015-01-07  2025.90  2005.55  2029.61  2005.55
# 2015-01-06  2002.61  2022.15  2030.25  1992.44
# 2015-01-05  2020.58  2054.44  2054.44  2017.34
# 2015-01-02  2058.20  2058.90  2072.36  2046.04
#
# [1855 rows x 4 columns]

# %%
# Calculate percentage of change in ETH closing price
eth_daily_returns= eth_df.pct_change().dropna()

eth_daily_returns.head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2021-05-28 -0.050639 -0.044098 -0.115888 -0.115689  -0.115689  0.198524
# 2021-05-29 -0.119747 -0.070409 -0.054731 -0.058016  -0.058016 -0.155638
# 2021-05-30 -0.056245 -0.036912 -0.008900  0.048603   0.048603 -0.233824
# 2021-05-31  0.047803  0.098563  0.041424  0.135815   0.135815  0.198278
# 2021-06-01  0.134200  0.008794  0.110399 -0.029992  -0.029992 -0.117526

# %%
# Calculate percentage of change in BTC closing price
btc_daily_returns= btc_df.pct_change().dropna()

btc_daily_returns.head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2021-05-28 -0.020597 -0.037708 -0.066282 -0.071269  -0.071269  0.277458
# 2021-05-29 -0.073309 -0.041755 -0.031200 -0.030297  -0.030297 -0.180600
# 2021-05-30 -0.030174 -0.022394 -0.005140  0.030681   0.030681 -0.300346
# 2021-05-31  0.030375  0.029329  0.021515  0.046379   0.046379  0.232691
# 2021-06-01  0.045857  0.011436  0.045124 -0.017355  -0.017355 -0.112034

# %%
btc_volume = btc_df.loc[:, "Volume"]

btc_volume.head()
# Out:
# Date
# 2021-05-27    43210968721
# 2021-05-28    55200191952
# 2021-05-29    45231013335
# 2021-05-30    31646080921
# 2021-05-31    39009847639
# Name: Volume, dtype: int64

# %%
eth_volume = eth_df.loc[:, "Volume"]

eth_volume.head()
# Out:
# Date
# 2021-05-27    33373635283
# 2021-05-28    39999114805
# 2021-05-29    33773720220
# 2021-05-30    25876619428
# 2021-05-31    31007383150
# Name: Volume, dtype: int64

# %%
eth_volume.plot(legend=True, figsize=(15,10), title= "Bitcoin and Ethereum Market Cap 2021-22", color='orange', label='Ethereum')
btc_volume.plot(legend=True, figsize=(15,10), color='blue', label='Bitcoin')
# Out:
# <AxesSubplot:title={'center':'Bitcoin and Ethereum Market Cap 2021-22'}, xlabel='Date'>

# %%
btc_df["Volatility"]=btc_df["Close"].pct_change().rolling(window=4).std().dropna()
btc_df.tail()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2022-05-23  30309.396484  30590.585938  28975.560547  29098.910156
# 2022-05-24  29101.125000  29774.355469  28786.589844  29655.585938
# 2022-05-25  29653.134766  30157.785156  29384.949219  29562.361328
# 2022-05-26  29564.777344  29834.160156  28261.906250  29267.224609
# 2022-05-27  29282.712891  29342.943359  28880.873047  28961.142578
#
#                Adj Close       Volume  Volatility
# Date
# 2022-05-23  29098.910156  31483454557    0.034558
# 2022-05-24  29655.585938  26616506245    0.031123
# 2022-05-25  29562.361328  27525063551    0.031178
# 2022-05-26  29267.224609  36774325352    0.024572
# 2022-05-27  28961.142578  40239730688    0.013904

# %%
eth_df["Volatility"]=eth_df["Close"].pct_change().rolling(window=4).std()
eth_df.tail()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-05-23  2042.344727  2080.333496  1964.386597  1972.181885  1972.181885
# 2022-05-24  1972.390869  1991.535522  1920.688110  1978.982788  1978.982788
# 2022-05-25  1978.677002  2014.369507  1943.938599  1944.827881  1944.827881
# 2022-05-26  1945.033325  1962.171143  1759.199585  1803.913330  1803.913330
# 2022-05-27  1803.849976  1805.196411  1741.441162  1752.477295  1752.477295
#
#                  Volume  Volatility
# Date
# 2022-05-23  16434529708    0.032373
# 2022-05-24  13057109007    0.028561
# 2022-05-25  13364545730    0.029879
# 2022-05-26  23458681818    0.032176
# 2022-05-27  27320891392    0.032037

# %%
sp_500_df["Volatility"]=sp_500_df["Price"].pct_change().rolling(window=4).std().dropna()
sp_500_df.tail()
# Out:
#               Price     Open     High      Low  Volatility
# Date
# 2015-01-08  2062.14  2030.61  2064.08  2030.61    0.002720
# 2015-01-07  2025.90  2005.55  2029.61  2005.55    0.012292
# 2015-01-06  2002.61  2022.15  2030.25  1992.44    0.013426
# 2015-01-05  2020.58  2054.44  2054.44  2017.34    0.013658
# 2015-01-02  2058.20  2058.90  2072.36  2046.04    0.017006

# %%
sp500_volatility = sp_500_df.loc[:, "Volatility"]

sp500_volatility.tail()
# Out:
# Date
# 2015-01-08    0.002720
# 2015-01-07    0.012292
# 2015-01-06    0.013426
# 2015-01-05    0.013658
# 2015-01-02    0.017006
# Name: Volatility, dtype: float64

# %%
btc_volatility= btc_df.loc[:,"Volatility"]

btc_volatility.tail()
# Out:
# Date
# 2022-05-23    0.034558
# 2022-05-24    0.031123
# 2022-05-25    0.031178
# 2022-05-26    0.024572
# 2022-05-27    0.013904
# Name: Volatility, dtype: float64

# %%
eth_volatility=eth_df.loc[:, "Volatility"]

eth_volatility.tail()
# Out:
# Date
# 2022-05-23    0.032373
# 2022-05-24    0.028561
# 2022-05-25    0.029879
# 2022-05-26    0.032176
# 2022-05-27    0.032037
# Name: Volatility, dtype: float64

# %%
btc_volatility.loc['2021-06-01':'2022-04-30'].plot(legend=True, figsize=(15,10), title="Crypto Volatility 2021-22 (Bitcoin and Ethereum)", color= "orange", label= "Bitcoin")
eth_volatility.loc['2021-06-01':'2022-04-30'].plot(legend=True, color="blue", label= "Ethereum")
sp500_volatility.loc['2021-06-01':'2022-04-30'].plot(legend=True, color="green", label="S&P 500")
# Out:
# <AxesSubplot:title={'center':'Crypto Volatility 2021-22 (Bitcoin and Ethereum)'}, xlabel='Date'>
